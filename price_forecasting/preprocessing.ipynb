# %% [markdown]
# <b>PART-I<b>

# %% [markdown]
# <b>Preprocessing of raw_wheat.csv to wheat.csv<b>

# %%
import pylab
import calendar
import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats
#import missingno as msno
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %matplotlib inline

# %%
daily_Data= pd.read_csv("jaunpur_wheat.csv")

# %%
daily_Data.head()
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1       Jaunpur     Jaunpur     Wheat    Dara   FAQ
# 1       2       Jaunpur     Jaunpur     Wheat    Dara   FAQ
# 2       3       Jaunpur     Jaunpur     Wheat    Dara   FAQ
# 3       4       Jaunpur     Jaunpur     Wheat    Dara   FAQ
# 4       5       Jaunpur     Jaunpur     Wheat    Dara   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0                     2020                     2080         2060  06-Apr-20
# 1                     2050                     2110         2090  05-Apr-20
# 2                     2060                     2100         2080  04-Apr-20
# 3                     2050                     2090         2075  03-Apr-20
# 4                     2020                     2075         2050  02-Apr-20

# %%
daily_Data.shape
# Out:
# (2681, 10)

# %%
df=daily_Data.copy()

# %%
df.columns
# Out:
# Index(['Sl no.', 'District Name', 'Market Name', 'Commodity', 'Variety',
#        'Grade', 'Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)',
#        'Modal_Price', 'Price_Date'],
#       dtype='object')

# %%
df=df.rename(index=str, columns={"Sl no.": "Sl_no", "Min Price (Rs./Quintal)": "Min_Price","Price Date":"Price_Date","Modal Price (Rs./Quintal)":"Modal_Price"})

# %%
df.head()
# Out:
#    Sl_no District Name Market Name Commodity Variety Grade  Min_Price  \
# 0      1       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2020
# 1      2       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2050
# 2      3       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2060
# 3      4       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2050
# 4      5       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2020
#
#    Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0                     2080         2060  06-Apr-20
# 1                     2110         2090  05-Apr-20
# 2                     2100         2080  04-Apr-20
# 3                     2090         2075  03-Apr-20
# 4                     2075         2050  02-Apr-20

# %%
df.columns
# Out:
# Index(['Sl_no', 'District Name', 'Market Name', 'Commodity', 'Variety',
#        'Grade', 'Min_Price', 'Max Price (Rs./Quintal)', 'Modal_Price',
#        'Price_Date'],
#       dtype='object')

# %%
df.Price_Date = pd.to_datetime(df.Price_Date, errors='coerce')

# %%
df.head()
# Out:
#    Sl_no District Name Market Name Commodity Variety Grade  Min_Price  \
# 0      1       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2020
# 1      2       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2050
# 2      3       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2060
# 3      4       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2050
# 4      5       Jaunpur     Jaunpur     Wheat    Dara   FAQ       2020
#
#    Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0                     2080         2060 2020-04-06
# 1                     2110         2090 2020-04-05
# 2                     2100         2080 2020-04-04
# 3                     2090         2075 2020-04-03
# 4                     2075         2050 2020-04-02

# %%
df=df.sort_values(by='Price_Date')

# %%
df.drop_duplicates('Price_Date', inplace = True)

# %%
df.head(20)
# Out:
#       Sl_no District Name Market Name Commodity Variety Grade  Min_Price  \
# 2680   2681       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2679   2680       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2678   2679       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2677   2678       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2676   2677       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2675   2676       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2674   2675       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2673   2674       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2672   2673       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2671   2672       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2670   2671       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2669   2670       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2668   2669       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2667   2668       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2666   2667       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2665   2666       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2664   2665       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2663   2664       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2662   2663       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
# 2661   2662       Jaunpur     Jaunpur     Wheat   Other   FAQ          0
#
#       Max Price (Rs./Quintal)  Modal_Price Price_Date
# 2680                        0         1150 2011-01-01
# 2679                        0         1150 2011-01-03
# 2678                        0         1150 2011-01-04
# 2677                        0         1150 2011-01-05
# 2676                        0         1150 2011-01-06
# 2675                        0         1150 2011-01-07
# 2674                        0         1175 2011-01-08
# 2673                        0         1175 2011-01-10
# 2672                        0         1175 2011-01-11
# 2671                        0         1175 2011-01-12
# 2670                        0         1175 2011-01-13
# 2669                        0         1175 2011-01-14
# 2668                        0         1175 2011-01-15
# 2667                        0         1175 2011-01-17
# 2666                        0         1200 2011-01-18
# 2665                        0         1200 2011-01-19
# 2664                        0         1200 2011-01-20
# 2663                        0         1200 2011-01-21
# 2662                        0         1200 2011-01-22
# 2661                        0         1200 2011-01-24

# %% [markdown]
# <b>Saving to wheat.csv for future price prediction<b>

# %%
df.to_csv("jaupur_processed_wheat.csv", sep=',')
